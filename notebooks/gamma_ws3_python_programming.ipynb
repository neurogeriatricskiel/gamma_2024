# %% [markdown]
# ## Python for Movement Sciences
# In this section, we will go through the basic programming concepts that you'll need for alaysis of the movement data.

# %% [markdown]
# ### Working with Google Colab
#
# Google Colab provides an environment for writing and executing Python code.
#
# ### Types of Cells:
# 1. **Code Cells**:
#    - These cells allow you to write and execute Python code.
#
# 2. **Text Cells** (Markdown):
#    - These cells allow you to write formatted text using **Markdown**.

# %% [markdown]
# **Examples**

# %% [markdown]
# - **Basic Python Code in a Code Cell:**

# %%
# A simple Python print statement
print("Hello, Welcome to Python Programming for the Movement Science Workshop!")

# Assign your name as string and print it
my_name = "Masoud"
print(my_name)
# Out:
# Hello, Welcome to Python Programming for the Movement Science Workshop!
# Masoud

# %% [markdown]
# - **Use Code Cell for Math Operations:**

# %%
# Basic math operation
a = 10
b = 5
print(a + b)
print("Summation:", a + b)
# Out:
# 15
# Summation: 15

# %% [markdown]
# **Exercise 1**
#
# - Open a code cell in your notebbok.
#
# - Create two variables `a` and `b`, assign them values of your choice (e.g.: a = 2 and b = 5), and print their sum.

# %% [markdown]
# ### Basics of Python Scripting

# %% [markdown]
# **Primary Data Types**
#
# **Scalars:**
#
# A **scalar** is a single value, like:
# - an integer (`10`)
# - a float (`4.2`)
# - a string (`"hello"`)
# - a complex number (`2 + 3j`)
# - a boolean (`True` or `False`)

# %% [markdown]
# **Examples**

# %% [markdown]
# - Define and print an integer scalar

# %%
my_int = 10                # Integer scalar
print(my_int)
print("Integer scalar:", my_int)
# Out:
# 10
# Integer scalar: 10

# %% [markdown]
# - Define and print an float scalar

# %%
my_float = 4.2            # Float scalar
print("Float scalar:", my_float)
# Out:
# Float scalar: 4.2

# %% [markdown]
# - Define and print an string scalar

# %%
my_string = "Welcome to GAMMA!"  # String scalar
print("String scalar:", my_string)
# Out:
# String scalar: Welcome to GAMMA!

# %% [markdown]
# **Exercise 2**
#
# - Open a Code cell.
# - Create an integer variable `age` and assign your current age to it (e.g.: 27).
# - Create a float variable `height` and assign your height in meters (e.g.: 1.72).
# - Multiply your `age` by `height` and print the result.

# %% [markdown]
# **Collections**
#
# They are data structures which can store multiple values.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Exmples for Dictrionaries**
#
# Dictionaries are used to store data values in `key` and `value` pairs.

# %% [markdown]
# - Define `my_dict` which is a dictionary with key-value pairs, where keys are `"name"`, `"age"`, and `"height"`, and their respective values are `"Masoud"`, `35`, and `1.92`.

# %%
# Defining a dictionary
my_dict = {
    "name": "Masoud",
    "age": 35,
    "height": 1.92,
}

# %% [markdown]
# - Access dictionary values using keys, such as `my_dict["name"]` for `"Masoud"`.

# %%
# Accessing elements of the dictionary
print(my_dict["name"])
# Out:
# Masoud

# %% [markdown]
# - Dictionaries are mutable, meaning you can change values (e.g., updating `"age"` from `35` to `26`).

# %%
# Updating a value in the dictionary
my_dict["age"] = 26
print(my_dict)
# Out:
# {'name': 'Masoud', 'age': 26, 'height': 1.92}

# %% [markdown]
# - New key-value pairs can be added (e.g., adding `"email": "Masoud.Abedinifar@uksh.de"`).

# %%
# Adding a new key-value pair
my_dict["email"] = "Masoud.Abedinifar@uksh.de"
print(my_dict)
# Out:
# {'name': 'Masoud', 'age': 26, 'height': 1.92, 'email': 'Masoud.Abedinifar@uksh.de'}

# %% [markdown]
# - Iterate through a dictionary using `.items()` to get both keys and values.

# %%
# Iterating through a dictionary
for key, value in my_dict.items():
    print(key, ":", value)
# Out:
# Dictionary items:
# name : Masoud
# age : 26
# height : 1.92
# email : Masoud.Abedinifar@uksh.de

# %% [markdown]
# **Exercise 3**
#
# - Create a dictionary called `personal_info` with the following keys and values:
#
#     `"name": "your_name"`
#
#     `"age": your_age`
#
# - Use a `for` loop to print each key and its corresponding value from the dictionary.

# %% [markdown]
# **Control structures**
#
#   - **If-Else Statements**:
#     - Used to make decisions based on conditions.
#
#   - **For Loops**:
#     - Used for iterating over a sequence.
#
#   - **While Loops**:
#     - Used for repeated execution as long as a condition is true.

# %% [markdown]
# **Control Structures Examples**

# %% [markdown]
# - An **if-else** statement is written by using the `if` and `else` keywords.

# %%
# If-Else Statement
movement_speed = 5.0  # Speed in meters per second

if movement_speed < 3.0:
    print("The movement is slow.")
elif movement_speed < 6.0:
    print("The movement is moderate.")
else:
    print("The movement is fast.")
# Out:
# The movement is moderate.

# %% [markdown]
# - A **for** statement is written by using the `for` keyword.

# %%
# Define constant movement speed 
movement_speed = 5.0  # Speed in meters per second

# Print movement data over 5 seconds
# To loop through a set of code a specified number of times, we can use the range() function

for second in range(1, 6):   # range(1, 6) means values from 1 to 6 (but not including 6)
    distance = movement_speed * second  # Calculate distance traveled
    print(f"At second {second}, distance traveled: {distance} meters")
# Out:
# At second 1, distance traveled: 5.0 meters
# At second 2, distance traveled: 10.0 meters
# At second 3, distance traveled: 15.0 meters
# At second 4, distance traveled: 20.0 meters
# At second 5, distance traveled: 25.0 meters

# %% [markdown]
# **Functions**
#
# They are blocks of code which only run when they are called.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example**
#
# - Write a funtion to calculate area of the rectangle using its length and width as input parameters and giving the area of the rectangle as an output.

# %%
# Defining a function to calculate the area of a rectangle given its length and width
def calculate_area(length, width):
    area = length * width
    return area

# Calling the function with arguments
area_of_rectangle = calculate_area(length=5, width=10)

# Displaying the result
print(area_of_rectangle)
# Out:
# 50

# %% [markdown]
# **Exercise 5**
#
# - Define a function named `calculate_distance` that takes two parameters: `velocity` (in meters per second) and `time` (in seconds). This function should calculate and return the distance using the formula:
#
#     `distance` = `velocity` × `time`
#
# - Call the function with example values (e.g., `velocity = 5` meters/second, `time = 12` seconds) and print the result.
#
# **Tip**: You need to define a function as follows:
#
# ```python
# # Define the function
# def function_name(parameter_1, parameter_2):
#     # Code to execute: calculate distance here
#     return function_result
#
# # Example call to the function
# example_result = function_name(parameter_1=velocity_value, parameter_2=time_value)
#
# # Print the example result
# print(example_result)
# ```

# %% [markdown]
# ### **Essential Python Packages**
#
# ![image.png](data:image/png;base64,...)
#
# **Commonly Used Packages**:
# - **NumPy**: For numerical computing and handling arrays.
# - **Pandas**: For data manipulation and analysis using data frames.
# - **Matplotlib**: For creating visualizations like plots and charts.
# - **SciPy**: For scientific computing with advanced mathematical functions.
#
# **Installation**:
# - Install packages easily in Google Colab using:
#   ```python
#   pip install numpy
#   ```
#
# **Application**:
# - For working with each packages, you can import them easily in Google Colab using:
#   ```python
#   import numpy as np
#   ````

# %% [markdown]
# **NumPy**
#
# [NumPY](https://numpy.org/doc/stable/reference/module_structure.html) is a powerful library which is commonly used for numerical computing.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **What is an “array”?**
#
# A one-dimensional array like a list:
#
# ![image.png](data:image/png;base64,...)
#
# A two-dimensional array would be like a table:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example:**

# %% [markdown]
# - Importing numpy library:

# %%
# Importing the NumPy library
import numpy as np

# %% [markdown]
# - Creating Arrays:

# %%
# Creating a NumPy array from a Python list
my_array = np.array([1, 2, 3])     # 1-dimensional array
print(my_array)
# Out:
# [1 2 3]

# %% [markdown]
# - Control Shape and Size of the Arrays:

# %%
# Control shape of the Array
my_array.shape   # the shape (rows,columns)
# Out:
# (3,)

# %%
# Control size of the Array
my_array.size    # number of elements
# Out:
# 3

# %% [markdown]
# - Basic Arithmetic Operations:

# %%
# Performing basic arithmetic operations
array_sum = my_array + 10
print(array_sum)
# Out:
# [11 12 13]

# %% [markdown]
# **Matplotlib**
#
# [Matplotlib](https://matplotlib.org/stable/users/index.html) is a low level graph plotting library that serves as a visualization utility.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Examples:**

# %% [markdown]
# Create a simple line plot to visualize a mathematical function, such as the sine function.

# %% [markdown]
# - Step 1
#
#    - Import necessary libraries such as numpy and matplotlib

# %%
# Importing the necessary libraries
import numpy as np

# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:
import matplotlib.pyplot as plt

# %% [markdown]
# - Step 2
#
#     - Create an artificial sample data using numpy library

# %%
# Creating sample data using Numpy library
x = np.linspace(0, 2*(np.pi), 100)  # Generate 100 points from 0 to 2*pi radians (full sine wave cycle)
print(f"x values are:", x)

# Compute the sine of each point in the x array
y = np.sin(x)
print(f"y values are:", y)
# Out:
# x values are: [0.         0.06346652 0.12693304 0.19039955 0.25386607 0.31733259
#  0.38079911 0.44426563 0.50773215 0.57119866 0.63466518 0.6981317
#  0.76159822 0.82506474 0.88853126 0.95199777 1.01546429 1.07893081
#  1.14239733 1.20586385 1.26933037 1.33279688 1.3962634  1.45972992
#  1.52319644 1.58666296 1.65012947 1.71359599 1.77706251 1.84052903
#  1.90399555 1.96746207 2.03092858 2.0943951  2.15786162 2.22132814
#  2.28479466 2.34826118 2.41172769 2.47519421 2.53866073 2.60212725
#  2.66559377 2.72906028 2.7925268  2.85599332 2.91945984 2.98292636
#  3.04639288 3.10985939 3.17332591 3.23679243 3.30025895 3.36372547
#  3.42719199 3.4906585  3.55412502 3.61759154 3.68105806 3.74452458
#  3.8079911  3.87145761 3.93492413 3.99839065 4.06185717 4.12532369
#  4.1887902  4.25225672 4.31572324 4.37918976 4.44265628 4.5061228
#  4.56958931 4.63305583 4.69652235 4.75998887 4.82345539 4.88692191
#  4.95038842 5.01385494 5.07732146 5.14078798 5.2042545  5.26772102
# ...

# %% [markdown]
# - Setp 3
#
#     - Create a simple line plot to visulaize data in x and y direction

# %%
# Creat a figure with specified size
plt.figure(figsize=(10, 5))  # Creates a figure with a size of 10x5 inches

# Plot the sine wave using simple line plots
plt.plot(x, y, color='blue', linewidth=2)  # Plots the sine wave with a blue line and width of 2

# Adding title and axis labels
plt.title('Simple Line Plot of Sine Function')  # Sets the title of the plot
plt.xlabel('X (radians)')  # Adds a label to the x-axis (representing radians)
plt.ylabel('Y (sin(x))')   # Adds a label to the y-axis (representing sin(x))

# Adding grid, legend, and displaying the plot
plt.show()  # Displays the plot

# %% [markdown]
# **Pandas**
#
# [Pandas](https://pandas.pydata.org/docs/user_guide/10min.html) is used for working with big data and make conclusions based on statistical theories.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The primary two components of pandas are:
#
# 1. **Series:** They are essentially single columns of data.
#
# 2.  **DataFrame:** They multi-dimensional tables made up of a collection of Series.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Examples:**
#
# Create a sample pandas series including acceleration data in x-direction and pandas dataframe including acceletion data.

# %% [markdown]
# - Import pandas library:

# %%
import pandas as pd

# %% [markdown]
# - Use `pd.Series()` to create Pandas Series.

# %%
# Create a dictionary including acceletion data in x axis direction
ACCEL_x = {
  "LowerBack_ACCEL_x": [0.920, 0.919, 0.922, 0.926, 0.918]
}

# Convert dictionary to a Pandas Series
Accel_x_series = pd.Series(ACCEL_x)
print(Accel_x_series)
# Out:
# LowerBack_ACCEL_x    [0.92, 0.919, 0.922, 0.926, 0.918]
# dtype: object

# %% [markdown]
# - Use `pd.DataFrame()` to create Pandas DataFrame.

# %%
# Create a dictionary including acceletion data in x, y and z axis direction
data = {
  "LowerBack_ACCEL_x": [0.920, 0.919, 0.922, 0.926, 0.918],
  "LowerBack_ACCEL_y": [-0.047, -0.051, -0.047, -0.048, -0.053],
  "LowerBack_ACCEL_z": [-0.400, -0.392, -0.392, -0.384, -0.397],
}

# Convert dictionary to a Pandas DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#    LowerBack_ACCEL_x  LowerBack_ACCEL_y  LowerBack_ACCEL_z
# 0              0.920             -0.047             -0.400
# 1              0.919             -0.051             -0.392
# 2              0.922             -0.047             -0.392
# 3              0.926             -0.048             -0.384
# 4              0.918             -0.053             -0.397

# %% [markdown]
# - Locate Row:
#
#    - You can use the `loc` attribute to return one or more specified row(s).

# %%
# Refer to the row index:
print(df.loc[0])
# Out:
# LowerBack_ACCEL_x    0.920
# LowerBack_ACCEL_y   -0.047
# LowerBack_ACCEL_z   -0.400
# Name: 0, dtype: float64

# %%
# Use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#    LowerBack_ACCEL_x  LowerBack_ACCEL_y  LowerBack_ACCEL_z
# 0              0.920             -0.047             -0.400
# 1              0.919             -0.051             -0.392

# %% [markdown]
# - Load Files Into a DataFrame:
#
#    - If your data sets are stored in a csv or a tsv file format, Pandas can load them into a DataFrame using `pd.read_csv()`.

# %%
## Load your csv data using Pandas Dataframe
# df = pd.read_csv('your_data_directory/sample_data.csv')
# print(df)

# %% [markdown]
# **SciPy**
#
# [Scipy](https://docs.scipy.org/doc/scipy/reference/index.html) is used for scientific computing with advanced mathematical functions
#
# ![image.png](data:image/png;base64,...)
#
# - **Applications:**
#
#   - **Data Analysis**
#   - **Optimization**
#   - **Signal Processing**
#   - **Interpolation**
#   - **Statistical Functions**

# %% [markdown]
# **Example**
#
# - Design a Butterworth low-pass filter.
#
# - Apply the designed filter to the artifical data with specified cutoff frequency, sampling rate and filter order.
#
# - Then, plot the the original and filtered data together.

# %% [markdown]
# - **Step 1**
#
#     - Import necessary libraries:

# %%
import numpy as np
from scipy.signal import butter, filtfilt
import matplotlib.pyplot as plt

# %% [markdown]
# - **Step 2**
#
#     - Use scipy library to design a lowpass Butterworth filter.
#     - Check [`Butterworth digital and analog filter design`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.butter.html) from scipy library.
#     - Check [`Apply a digital filter forward and backward to a signal`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.filtfilt.html) from scipy library.

# %%
# Define a function to apply a Butterworth low-pass filter to the input data with specified cutoff frequency, sampling rate and filter order
def butter_lowpass_filter(data, cutoff, fs, order):
    # Calculate the Nyquist frequency, which is half the sampling frequency
    nyq = 0.5 * fs

    # Normalize the cutoff frequency by the Nyquist frequency
    # This gives a value between 0 and 1, which is required by the Butterworth filter
    normal_cutoff = cutoff / nyq

    # Design a Butterworth low-pass filter with the specified order and normalized cutoff frequency
    b, a = butter(N=order, Wn=normal_cutoff, btype='low', analog=False)

    # Apply the filter to the input data using filtfilt, which performs forward and backward filtering
    # This helps to minimize phase distortion
    filtered_data = filtfilt(b, a, data)

    return filtered_data

# %% [markdown]
# - **Step 3**
#
#     - Create artifical data using numpy library to filter with the designed lowpass filter

# %%
# Create time array using `np.linspace` which generates 1000 equally spaced values between 0 and 10 seconds.
time = np.linspace(0, 10, 1000)

# Create artifical data using numpy library 
# The data is the sine wave (A*sin(2π*f*t)) with frequency (f) of 2 Hz and magnitude (A) of 10.
# The random noise with `np.random.normal` is added to simulate measurement noise.
artificial_data = 10 * np.sin(2 * np.pi * 2 * time) + np.random.normal(0, 1, 1000)

# %% [markdown]
# - **Step 4**
#
#   - Apply the designed low-pass filter to the created artifical data with the following filter parameters:
#
#     cutoff frequency (`cutoff`) = 6 Hz,
#
#     sampling frequency (`fs`) = 100 Hz,
#
#     filter order (`order`) = 4

# %%
# Apply the designed low-pass filter to the created artifical data 
filtered_data = butter_lowpass_filter(data=artificial_data, cutoff=6, fs=100, order=4)

# %% [markdown]
# - **Setp 5**
#
#     - Plot the original and filtered data

# %%
# Define the figure size as 10 by 6 inches for better readability.
plt.figure(figsize=(10, 6))

# Plot the original noisy data
# - Plot time on the x-axis and the original data on the y-axis.
# - Label it as 'Original Data' for the legend to distinguish it from the filtered data.
plt.plot(time, artificial_data, color='red', label='Original Data')

# Plot the filtered data on the same figure
# - Add another plot with the filtered data and label it as 'Filtered Data'.
plt.plot(time, filtered_data, color='blue', label='Filtered Data')

# Add axis labels and title to provide context for the plot
# - x-axis labeled 'Time (s)' indicating time in seconds.
# - y-axis labeled 'Joint Angle (degrees)' indicating the signal type.
# - Title describes the plot content: Original and Filtered Data.
plt.xlabel('Time (s)')
plt.ylabel('Data')
plt.title('Original and Filtered Data')

# Add a legend to identify the original and filtered data lines
# - This helps distinguish between the two data sets on the plot.
plt.legend()

# Display a grid to make it easier to analyze the data visually
# - The grid adds horizontal and vertical lines for reference.
plt.grid(True)

# Display the plot
# - Finally, show the plot with all elements included.
plt.show()

# %% [markdown]
# **Exercise 6**
#
# Create artificial data using `numpy` library and plot it as a simple line plot using `matplotlib` library.
#
# - **Step 0: Import Necessary Libraries**
#    - Import the required libraries.
#
#    **Tip**
#    -  You will need to import `numpy` and `matplotlib.pyplot`
#
# - **Step 1: Generate a Noisy Signal**
#    - Create a time vector `time` that spans from 0 to 10 seconds with 1000 samples using `np.linspace`.
#    - Create a noisy signal composed of a 2 Hz sine wave with added Gaussian noise.
#
#    **Tips:**
#    - For creating the noisy signal, you may use the following information:
#      - Sine signal: `A * sin(2π * f * time)` with `A = 10` and `f = 2` Hz.
#      - You can use `np.random.normal(0, 1, 1000)` to generate noise and then add it to the signal.
#
# - **Step 2: Plot the Results**
#    - Use Matplotlib to plot the noisy signal.
#    - You may also add appropriate title and lables to plot, for example:
#
#     Title: `Line Plot of Sine Function`
#
#     Label for y-axis: `Amplitude`
#
#     Label for x-axis: `Time(s)`

# %% [markdown]
# For detailed explanations about working with different Python libraries you may also use [appendix notebook](https://github.com/neurogeriatricskiel/gamma_2024/blob/main/notebooks/appendix.ipynb) in GAMMA repository.

# %% [markdown]
# ### Working with movement data
#
# 1. Motion Capture Data
#
# 2. Inertial Measurement Unit (IMU) Data

# %% [markdown]
# #### 1. Motion Capture Data
#
# Motion capture (mocap) is the process of recording the movement of people using cameras. The mocap data is generally saved as C3D files.
#
# Loading C3D Files
#
#   -  We will use [C3D](https://c3d.readthedocs.io/en/stable/) package to load C3D files.

# %%
pip install c3d
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
#   - Load data
#
#     - We’ll use a [sample_data.c3d](https://github.com/neurogeriatricskiel/gamma_2024/blob/main/datasets/c3d%20data/sample_data.c3d) file directly from our GitHub repository.
#
#     - Instead of manually downloading the file, we use `requests.get(url)` to retrieve the file from the URL.

# %%
import requests  # Library for making HTTP requests to get data from URLs
import c3d      # Library for reading and processing C3D files used in motion capture
import numpy as np  # Fundamental package for numerical operations and handling arrays
import matplotlib.pyplot as plt  # Library for creating visualizations and plots
import io  # The module provides a set of classes and functions to handle "Input/Output" operations such as reading from or writing to files, networks, or other data sources

# URL of the C3D file to be downloaded
url = "https://github.com/neurogeriatricskiel/gamma_2024/raw/main/datasets/c3d%20data/sample_data.c3d"

# Make an HTTP GET request to retrieve the C3D file from the specified URL
response = requests.get(url)

# Get the raw binary content of the response (the actual C3D file data)
raw_binary_content = response.content

# Create a BytesIO object to read the binary content as if it were a file
file_handle = io.BytesIO(raw_binary_content)

# %% [markdown]
# - Store Data
#
#   - The file content is accessed using a binary [Reader](https://c3d.readthedocs.io/en/master/generated/c3d.Reader.html) from `c3d` library.
#
#   - The `read_frames` method generates tuples containing the frame index, a numpy array of point data, and a numpy array of analog data.

# %%
# Initialize an empty list to store all the point data from the C3D file
all_points_data = []

# Open the C3D file in binary read mode using BytesIO
# Create a reader object for reading frames from the C3D file using Reader instance
reader = c3d.Reader(file_handle)   # Read metadata and C3D motion frames from the given file handle

# Iterate through each frame in the C3D file
for frame_ind, points, analog in reader.read_frames():
    # Append the point data (3D coordinates of markers) from each frame to the list
    all_points_data.append(points)

print("Shape of all_points_array:", all_points_data)
# Out:
# Shape of all_points_array: [array([[-2.08499619e+02,  4.31736145e+02,  4.54223541e+02,
#          0.00000000e+00,  0.00000000e+00],
#        [-4.79439972e+02,  6.58247498e+02,  4.46473022e+02,
#          0.00000000e+00,  0.00000000e+00],
#        [-2.11992813e+02,  3.68749603e+02,  2.35899307e+02,
#          0.00000000e+00,  0.00000000e+00],
#        [-4.37412567e+02,  7.62169861e+02,  5.90348694e+02,
#          0.00000000e+00,  0.00000000e+00],
#        [-2.32406128e+02,  3.28905426e+02,  6.00937378e+02,
#          0.00000000e+00,  0.00000000e+00],
#        [-6.05958862e+02,  7.03440613e+02,  2.60024139e+02,
#          0.00000000e+00,  0.00000000e+00],
#        [-4.75182648e+02,  5.91003662e+02,  1.71384506e+01,
#          0.00000000e+00,  0.00000000e+00],
#        [-1.00647461e+02,  4.70161194e+02,  5.37077560e+01,
#          0.00000000e+00,  0.00000000e+00],
#        [-6.02138184e+02,  5.97444214e+02,  4.77038422e+01,
#          0.00000000e+00,  0.00000000e+00],
# ...

# %% [markdown]
# **Alternatively** you can also download the sample C3D data and use it from local memory by using the following code (you just need to uncomment the code):

# %%
# Import the c3d package for reading C3D files and Numpy for array manipulations
# import c3d
# import numpy as np
# import matplotlib.pyplot as plt

# # Path to the dataset 
# file_path = 'C:/Users/Project/Desktop/sample_data.c3d'  # your data path

# # Initialize an empty list to store all the point data from the C3D file
# all_points_data = []

# # Open the C3D file in binary read mode ('rb') using the file path
# with open(file_path, 'rb') as handle:
#     # Create a reader object for reading frames from the C3D file
#     reader = c3d.Reader(handle)

#     # Iterate through each frame in the C3D file
#     # Each iteration gives the frame number, point data, and analog data
#     for frame_no, points, _ in reader.read_frames():
#         # Append the point data (3D coordinates of markers) from each frame to the list
#         all_points_data.append(points)

# # Convert the list of point data into a NumPy array for easier manipulation and analysis
# all_points_array = np.array(all_points_data)

# %%
# Print type of data points
type(all_points_data)
# Out:
# list

# %% [markdown]
#   - Convert the data points from each frame into a NumPy array for for further analysis.

# %%
# Convert the list of point data into a NumPy array for easier manipulation and analysis
all_points_array = np.array(all_points_data)
print(f"Type of all_points_array:", type(all_points_array))

# Print the shape of the data structure
print("Shape of all_points_array:", all_points_array.shape)
# Out:
# Type of all_points_array: <class 'numpy.ndarray'>
# Shape of all_points_array: (142, 77, 5)

# %% [markdown]
#   - Summary of Output
#
#     - 142 frames of data are available (data points).
#
#     - Each frame has data for 77 markers.
#
#     - Each marker's data consists of 5 attributes (typically three positional coordinates and two additional attributes).

# %% [markdown]
# - Extract labels using `reader`

# %%
# Extract the point labels
point_labels = np.array(reader.point_labels)  # Ensure point_labels is a NumPy array

# Display the point labels for debugging purposes
print("Point Labels:", point_labels)
# Out:
# Point Labels: ['A22:RKNE                      ' 'A22:LKNE                      '
#  'A22:RTIB                      ' 'A22:LTHI                      '
#  'A22:RTHI                      ' 'A22:LTIB                      '
#  'A22:LTOE                      ' 'A22:RANK                      '
#  'A22:LANK                      ' 'A22:RASI                      '
#  'A22:LASI                      ' 'A22:RTOE                      '
#  'A22:SACR                      ' 'A22:LHipAngles                '
#  'A22:LKneeAngles               ' 'A22:LAnkleAngles              '
#  'A22:RHipAngles                ' 'A22:RKneeAngles               '
#  'A22:RAnkleAngles              ' 'A22:LPelvisAngles             '
#  'A22:RPelvisAngles             ' 'A22:LFootProgressAngles       '
#  'A22:RFootProgressAngles       ' 'A22:LHipPower                 '
#  'A22:LKneePower                ' 'A22:LAnklePower               '
#  'A22:RHipPower                 ' 'A22:RKneePower                '
# ...

# %% [markdown]
# - Find the index of right and left knee angles.

# %%
# Find the index of 'A22:RKneeAngles' in the point_labels array
# np.where returns the indices where the condition is true (where the label matches 'A22:RKneeAngles')
r_knee_angles_index_in_array = np.where(point_labels == 'A22:RKneeAngles               ')[0]
print(f"Index of right knee angles:", r_knee_angles_index_in_array)

# Find the index of 'A22:LKneeAngles' in the point_labels array
# This does the same thing as above, but for the left knee angles
l_knee_angles_index_in_array = np.where(point_labels == 'A22:LKneeAngles               ')[0]
print(f"Index of left knee angles:", l_knee_angles_index_in_array)
# Out:
# Index of right knee angles: [17]
# Index of left knee angles: [14]

# %% [markdown]
# - Get the value of first index of the knee data

# %%
# Since np.where() returns an array, this ensures we only take the first match (index 0)
r_knee_angles_index = r_knee_angles_index_in_array[0]
print(f"Index of right knee angles:",r_knee_angles_index)

# Get the first index of the left knee data
# Similarly, this retrieves the first match for the left knee data
l_knee_angles_index = l_knee_angles_index_in_array[0]
print(f"Index of left knee angles:",l_knee_angles_index)
# Out:
# Index of right knee angles: 17
# Index of left knee angles: 14

# %% [markdown]
# - Extract and print the angles of right and left knees in x-direction.

# %%
# Extract the x-axis (first dimension, i.e., angle data along the x-direction) 
# for the 'RKneeAngles' from the point data array
# all_points_array[:, r_knee_angles_index, 0] selects the first dimension (x-axis) of the data 
# across all frames for the right knee angles
x_data_r_knee_angles = all_points_array[:, r_knee_angles_index, 0]
print(f"Right knee Angle data:",x_data_r_knee_angles)

# Similarly, extract the x-axis (first dimension) for the 'LKneeAngles' from the point data array
x_data_l_knee_angles = all_points_array[:, l_knee_angles_index, 0]
print(f"Left knee Angle data:",x_data_l_knee_angles)
# Out:
# Right knee Angle data: [-1.3099453  -3.2748632  -3.8206737  -3.1657012  -1.6374316   0.43664843
#   2.6198907   4.8031325   6.440564    7.423023    7.968834    7.7505097
#   7.204699    6.113078    4.8031325   3.2748632   1.6374316   0.
#  -1.3099453  -2.6198907  -3.7115116  -4.6939707  -5.348943   -5.7855916
#  -5.7855916  -5.348943   -4.2573223  -2.5107284   0.10916211  3.6023495
#   8.187158   13.536101   19.64918    26.308067   33.29444    39.95333
#  46.06641    50.86954    54.035244   55.34519    54.90854    52.616135
#  48.795464   43.337357   36.460144   28.818796   20.7408     13.099453
#   6.3314023   1.3099453  -1.7465937  -2.8382149  -2.2924042  -0.32748634
#   2.07408     4.6939707   6.8772125   8.405482    9.169617    9.278779
#   8.732968    7.8596716   6.7680507   5.348943    3.9298358   2.5107284
#   0.98245895 -0.21832421 -1.4191074  -2.5107284  -3.2748632  -3.7115116
#  -3.7115116  -3.056539   -1.7465937   0.32748634  3.3840253   7.204699
# ...

# %% [markdown]
# - Plot the angles of right and left knees in x-direction.

# %%
# Plot the extracted right and left knee angles over time
plt.figure(figsize=(10, 5))
plt.plot(x_data_r_knee_angles, label='Right Knee Angles in x-direction', color='blue')
plt.plot(x_data_l_knee_angles, label='Left Knee Angles in x-direction', color='red')
plt.xlabel('Frame')
plt.ylabel('Angle')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# There are also other packages to read and analyze c3d files such as:
#   - [ezc3d](https://github.com/pyomeca/ezc3d): read/write c3d files (actually part of pyomeca...)
#   - [Pyomeca](https://pyomeca.github.io/): biomechanical analysis toolbox
#   - [kineticstoolkit](https://kineticstoolkit.uqam.ca/doc/): biomechanical analysis toolbox

# %% [markdown]
# #### 2. Movement data from Inertial Measurement Unit (IMU) sensors

# %% [markdown]
# IMUs:
#
#   - Are one of the common sensors which provide motion data in a time-series format.
#
#   - Contain accelerometer and gyroscope data (sometimes also a magnetometer and rarely also a barometer).

# %% [markdown]
# **Load IMU Data**

# %% [markdown]
#   - We will load data from the Keep Control validation dataset which is publicaly available (Warmerdam et al., 2022) [Keep Control Dataset](https://github.com/neurogeriatricskiel/gamma_2024/tree/main/datasets/keepcontrol).
#
#   - The dataset contains simulatenous recording from at least 15 inertial measurement units (IMUs) attached to different parts of body of the participants.
#
#   - Participants performed a series of mobility tasks, such as walking, turning, and sit-to-stand, while wearing the IMUs.
#
#   - IMU data are stored in two separate [TSV files](https://github.com/neurogeriatricskiel/gamma_2024/tree/main/datasets/keepcontrol/sub-pp002/motion):
#
#     1. **Channels File**: Contains metadata for each IMU channel, such channel names, measurement units, sampling frequencies, etc.
#
#     2. **Data File**: Contains the actual IMU data for each channel (e.g., accelerometer and gyroscope data) across different tracked points.

# %% [markdown]
# **Step 1**
# - Import necessary libraries:

# %%
import numpy as np  # Import the NumPy library for numerical operations and array handling
import pandas as pd  # Import the pandas library for data manipulation and analysis
import matplotlib.pyplot as plt  # Import the Matplotlib library for creating visualizations

# %% [markdown]
# **Step 2**
# - Load [channel file](https://github.com/neurogeriatricskiel/gamma_2024/blob/main/datasets/keepcontrol/sub-pp002/motion/sub-pp002_task-walkFast_tracksys-imu_channels.tsv) for `sub-002` performaing `walkFast` task using pandas library.

# %%
# URL of the raw .tsv file on GitHub containing IMU channel information
channel_url = "https://github.com/neurogeriatricskiel/gamma_2024/blob/main/datasets/keepcontrol/sub-pp002/motion/sub-pp002_task-walkFast_tracksys-imu_channels.tsv?raw=True"

# Read the TSV file into a DataFrame using pandas dataframe library
# The header=0 argument specifies that the first row contains column names
# The sep="\t" argument indicates that the file is tab-separated
df_channel = pd.read_csv(channel_url, header=0, sep="\t")

# Display the first few rows of the DataFrame to inspect the channel information
df_channel.head()
# Out:
#            name component   type tracked_point  units  sampling_frequency
# 0  head_ACCEL_x         x  ACCEL          head      g                 200
# 1  head_ACCEL_y         y  ACCEL          head      g                 200
# 2  head_ACCEL_z         z  ACCEL          head      g                 200
# 3   head_GYRO_x         x   GYRO          head  deg/s                 200
# 4   head_GYRO_y         y   GYRO          head  deg/s                 200

# %% [markdown]
# - Extract channel names

# %%
# The 'name' column contains the names of the IMU channels
channel_names = df_channel["name"].values

# Print the extracted channel names
print(channel_names)
# Out:
# ['head_ACCEL_x' 'head_ACCEL_y' 'head_ACCEL_z' 'head_GYRO_x' 'head_GYRO_y'
#  'head_GYRO_z' 'head_MAGN_x' 'head_MAGN_y' 'head_MAGN_z' 'sternum_ACCEL_x'
#  'sternum_ACCEL_y' 'sternum_ACCEL_z' 'sternum_GYRO_x' 'sternum_GYRO_y'
#  'sternum_GYRO_z' 'sternum_MAGN_x' 'sternum_MAGN_y' 'sternum_MAGN_z'
#  'left_upper_arm_ACCEL_x' 'left_upper_arm_ACCEL_y'
#  'left_upper_arm_ACCEL_z' 'left_upper_arm_GYRO_x' 'left_upper_arm_GYRO_y'
#  'left_upper_arm_GYRO_z' 'left_upper_arm_MAGN_x' 'left_upper_arm_MAGN_y'
#  'left_upper_arm_MAGN_z' 'left_fore_arm_ACCEL_x' 'left_fore_arm_ACCEL_y'
#  'left_fore_arm_ACCEL_z' 'left_fore_arm_GYRO_x' 'left_fore_arm_GYRO_y'
#  'left_fore_arm_GYRO_z' 'left_fore_arm_MAGN_x' 'left_fore_arm_MAGN_y'
#  'left_fore_arm_MAGN_z' 'right_upper_arm_ACCEL_x'
#  'right_upper_arm_ACCEL_y' 'right_upper_arm_ACCEL_z'
#  'right_upper_arm_GYRO_x' 'right_upper_arm_GYRO_y'
#  'right_upper_arm_GYRO_z' 'right_upper_arm_MAGN_x'
#  'right_upper_arm_MAGN_y' 'right_upper_arm_MAGN_z'
# ...

# %% [markdown]
# - Extract channel types

# %%
# The 'type' column contains the types of the IMU channels
channel_type = df_channel["type"].values

# Print the extracted channel types
print(channel_type)
# Out:
# ['ACCEL' 'ACCEL' 'ACCEL' 'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL'
#  'ACCEL' 'ACCEL' 'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL' 'ACCEL'
#  'ACCEL' 'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL' 'ACCEL' 'ACCEL'
#  'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL' 'ACCEL' 'ACCEL' 'GYRO'
#  'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL' 'ACCEL' 'ACCEL' 'GYRO' 'GYRO'
#  'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL' 'ACCEL' 'ACCEL' 'GYRO' 'GYRO' 'GYRO'
#  'MAGN' 'MAGN' 'MAGN' 'ACCEL' 'ACCEL' 'ACCEL' 'GYRO' 'GYRO' 'GYRO' 'MAGN'
#  'MAGN' 'MAGN' 'ACCEL' 'ACCEL' 'ACCEL' 'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN'
#  'MAGN' 'ACCEL' 'ACCEL' 'ACCEL' 'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN'
#  'ACCEL' 'ACCEL' 'ACCEL' 'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL'
#  'ACCEL' 'ACCEL' 'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL' 'ACCEL'
#  'ACCEL' 'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL' 'ACCEL' 'ACCEL'
#  'GYRO' 'GYRO' 'GYRO' 'MAGN' 'MAGN' 'MAGN' 'ACCEL' 'ACCEL' 'ACCEL' 'GYRO'
# ...

# %% [markdown]
# - Extract tracked points

# %%
# The 'tracked_point' column contains the types of the IMU channels
channel_tracked_points = df_channel["tracked_point"].values

# Print the extracted tracked points
print(channel_tracked_points)
# Out:
# ['head' 'head' 'head' 'head' 'head' 'head' 'head' 'head' 'head' 'sternum'
#  'sternum' 'sternum' 'sternum' 'sternum' 'sternum' 'sternum' 'sternum'
#  'sternum' 'left_upper_arm' 'left_upper_arm' 'left_upper_arm'
#  'left_upper_arm' 'left_upper_arm' 'left_upper_arm' 'left_upper_arm'
#  'left_upper_arm' 'left_upper_arm' 'left_fore_arm' 'left_fore_arm'
#  'left_fore_arm' 'left_fore_arm' 'left_fore_arm' 'left_fore_arm'
#  'left_fore_arm' 'left_fore_arm' 'left_fore_arm' 'right_upper_arm'
#  'right_upper_arm' 'right_upper_arm' 'right_upper_arm' 'right_upper_arm'
#  'right_upper_arm' 'right_upper_arm' 'right_upper_arm' 'right_upper_arm'
#  'right_fore_arm' 'right_fore_arm' 'right_fore_arm' 'right_fore_arm'
#  'right_fore_arm' 'right_fore_arm' 'right_fore_arm' 'right_fore_arm'
#  'right_fore_arm' 'pelvis' 'pelvis' 'pelvis' 'pelvis' 'pelvis' 'pelvis'
#  'pelvis' 'pelvis' 'pelvis' 'left_thigh' 'left_thigh' 'left_thigh'
#  'left_thigh' 'left_thigh' 'left_thigh' 'left_thigh' 'left_thigh'
# ...

# %% [markdown]
# **Step 3**
# - Load [motion data file](https://github.com/neurogeriatricskiel/gamma_2024/blob/main/datasets/keepcontrol/sub-pp002/motion/sub-pp002_task-walkFast_tracksys-imu_motion.tsv) for `sub-002` performaing `walkFast` task using pandas library.

# %%
# URL of the raw .tsv file containing IMU motion data on GitHub
motion_data_url = "https://github.com/neurogeriatricskiel/gamma_2024/blob/main/datasets/keepcontrol/sub-pp002/motion/sub-pp002_task-walkFast_tracksys-imu_motion.tsv?raw=True"

# Read the motion data from the .tsv file into a pandas DataFrame
df_data = pd.read_csv(motion_data_url, header=0, sep="\t")

# Display the first few rows of the DataFrame to understand its structure and contents
df_data.head()
# Out:
#    head_ACCEL_x  head_ACCEL_y  head_ACCEL_z  head_GYRO_x  head_GYRO_y  \
# 0      0.877932      0.045904     -0.509266    -1.135622    -0.961020
# 1      0.873036      0.045904     -0.503404    -0.787838    -0.874312
# 2      0.877463      0.048830     -0.497063    -0.088720    -0.699088
# 3      0.870120      0.046385     -0.505378    -1.398235    -0.961020
# 4      0.871578      0.048830     -0.500981    -0.787838     0.000000
#
#    head_GYRO_z  head_MAGN_x  head_MAGN_y  head_MAGN_z  sternum_ACCEL_x  ...  \
# 0    -1.573915     -0.74902     0.457526     0.563468         0.937974  ...
# 1    -2.098553     -0.74902     0.455082     0.546872         0.936988  ...
# 2    -0.962440     -0.74902     0.452638     0.530275         0.938467  ...
# 3    -1.660751     -0.74634     0.455317     0.528807         0.937481  ...
# 4    -1.660751     -0.74366     0.458011     0.527338         0.945803  ...
#
#    left_ankle_MAGN_z  right_ankle_ACCEL_x  right_ankle_ACCEL_y  \
# ...

# %% [markdown]
# **Step 4**
# - Extract columns from data that match the extracted channel names

# %%
# This ensures that we only keep the relevant IMU data associated with the specified channels
df_data = df_data[channel_names]

# Print the filtered DataFrame to verify that it contains only the desired columns
print(df_data)
# Out:
#       head_ACCEL_x  head_ACCEL_y  head_ACCEL_z  head_GYRO_x  head_GYRO_y  \
# 0         0.877932      0.045904     -0.509266    -1.135622    -0.961020
# 1         0.873036      0.045904     -0.503404    -0.787838    -0.874312
# 2         0.877463      0.048830     -0.497063    -0.088720    -0.699088
# 3         0.870120      0.046385     -0.505378    -1.398235    -0.961020
# 4         0.871578      0.048830     -0.500981    -0.787838     0.000000
# ...            ...           ...           ...          ...          ...
# 1373      0.831528     -0.012695     -0.482917   -29.728458     2.447711
# 1374      0.817362     -0.013190     -0.479478   -28.851900     1.573400
# 1375      0.810539     -0.016117     -0.488779   -27.364944    -0.523864
# 1376      0.798352     -0.021489     -0.488779   -26.055429    -1.748623
# 1377      0.793925     -0.019043     -0.485340   -25.441484    -2.361002
#
#       head_GYRO_z  head_MAGN_x  head_MAGN_y  head_MAGN_z  sternum_ACCEL_x  \
# ...

# %% [markdown]
# **Step 5**
# - Store channel and imu motion data in Dictionary data structure

# %%
# Initialize an empty dictionary to store IMU data
imu_data_dict = {}

# Store the filtered IMU data DataFrame in the dictionary under the key "imu"
# This allows for easy access to the IMU data later in the analysis
imu_data_dict["imu"] = df_data

# Print the dictionary to verify that it contains the IMU data
print(imu_data_dict)
# Out:
# {'imu':       head_ACCEL_x  head_ACCEL_y  head_ACCEL_z  head_GYRO_x  head_GYRO_y  \
# 0         0.877932      0.045904     -0.509266    -1.135622    -0.961020
# 1         0.873036      0.045904     -0.503404    -0.787838    -0.874312
# 2         0.877463      0.048830     -0.497063    -0.088720    -0.699088
# 3         0.870120      0.046385     -0.505378    -1.398235    -0.961020
# 4         0.871578      0.048830     -0.500981    -0.787838     0.000000
# ...            ...           ...           ...          ...          ...
# 1373      0.831528     -0.012695     -0.482917   -29.728458     2.447711
# 1374      0.817362     -0.013190     -0.479478   -28.851900     1.573400
# 1375      0.810539     -0.016117     -0.488779   -27.364944    -0.523864
# 1376      0.798352     -0.021489     -0.488779   -26.055429    -1.748623
# 1377      0.793925     -0.019043     -0.485340   -25.441484    -2.361002
#
#       head_GYRO_z  head_MAGN_x  head_MAGN_y  head_MAGN_z  sternum_ACCEL_x  \
# ...

# %%
# Initialize an empty dictionary to store IMU channel information
imu_channels_dict = {}

# Store the IMU channel DataFrame in the dictionary under the key "imu"
# This organization helps in accessing the channel information later in the analysis
imu_channels_dict["imu"] = df_channel

# Print the dictionary to verify that it contains the IMU channel information
print(imu_channels_dict)
# Out:
# {'imu':                    name component   type tracked_point  units  \
# 0          head_ACCEL_x         x  ACCEL          head      g
# 1          head_ACCEL_y         y  ACCEL          head      g
# 2          head_ACCEL_z         z  ACCEL          head      g
# 3           head_GYRO_x         x   GYRO          head  deg/s
# 4           head_GYRO_y         y   GYRO          head  deg/s
# ..                  ...       ...    ...           ...    ...
# 130  right_ankle_GYRO_y         y   GYRO   right_ankle  deg/s
# 131  right_ankle_GYRO_z         z   GYRO   right_ankle  deg/s
# 132  right_ankle_MAGN_x         x   MAGN   right_ankle  Gauss
# 133  right_ankle_MAGN_y         y   MAGN   right_ankle  Gauss
# 134  right_ankle_MAGN_z         z   MAGN   right_ankle  Gauss
#
#      sampling_frequency
# 0                   200
# 1                   200
# 2                   200
# 3                   200
# 4                   200
# ..                  ...
# 130                 200
# ...

# %% [markdown]
# Now both `imu_data_dict` and `imu_channel_dict` are dictionaries, where the keys are the name of the tracking system (`imu`), and the values DataFrame.

# %% [markdown]
# **Step 6**
# - Extract Sampling Frequency

# %%
# Step 1: Filter the rows to only include those where the tracked point is 'pelvis'
pelvis_data = imu_channels_dict['imu'][imu_channels_dict['imu']['tracked_point'] == 'pelvis']
print(f"Pelvis data:", pelvis_data)

# Step 2: Select the 'sampling_frequency' column from the filtered data
pelvis_sampling_frequencies = pelvis_data['sampling_frequency']
print(f"Info of the sampling frequency of pelvis:", pelvis_sampling_frequencies)

# Step 3: Get the unique sampling frequency value (assuming there’s only one unique value)
sampling_frequency = pelvis_sampling_frequencies.unique()[0]
print(f"The sampling frequency for the pelvis data is: {sampling_frequency} Hz")
# Out:
# Pelvis data:               name component   type tracked_point  units  sampling_frequency
# 54  pelvis_ACCEL_x         x  ACCEL        pelvis      g                 200
# 55  pelvis_ACCEL_y         y  ACCEL        pelvis      g                 200
# 56  pelvis_ACCEL_z         z  ACCEL        pelvis      g                 200
# 57   pelvis_GYRO_x         x   GYRO        pelvis  deg/s                 200
# 58   pelvis_GYRO_y         y   GYRO        pelvis  deg/s                 200
# 59   pelvis_GYRO_z         z   GYRO        pelvis  deg/s                 200
# 60   pelvis_MAGN_x         x   MAGN        pelvis  Gauss                 200
# 61   pelvis_MAGN_y         y   MAGN        pelvis  Gauss                 200
# 62   pelvis_MAGN_z         z   MAGN        pelvis  Gauss                 200
# Info of the sampling frequency of pelvis: 54    200
# 55    200
# 56    200
# 57    200
# 58    200
# 59    200
# 60    200
# 61    200
# 62    200
# Name: sampling_frequency, dtype: int64
# ...

# %% [markdown]
# - Map each unique channel type to its corresponding unit.

# %%
# Step 1: Get the unique channel types from the DataFrame
unique_channel_types = imu_channels_dict["imu"]["type"].unique()
print(f"Unique channel types:",unique_channel_types)

# Step 2: Create an empty dictionary to store the mapping
mapping_type_units = {}

# Step 3: Iterate over each unique channel type to fill the dictionary
for ch_type in unique_channel_types:
    # Get the units for the current channel type
    units = imu_channels_dict["imu"][imu_channels_dict["imu"]["type"] == ch_type]["units"].iloc[0]

    # Add the channel type and its units to the dictionary
    mapping_type_units[ch_type] = units

# Step 4: Print the mapping of channel types to their respective units
print(f"The mapping of channel types to units is: {mapping_type_units}")
# Out:
# Unique channel types: ['ACCEL' 'GYRO' 'MAGN']
# The mapping of channel types to units is: {'ACCEL': 'g', 'GYRO': 'deg/s', 'MAGN': 'Gauss'}

# %% [markdown]
# -   Check tracked points

# %%
# Extract all unique values from the 'tracked_point' column in the IMU channels DataFrame.
# This identifies all the body parts where IMU sensors are placed in the dataset.
tracked_points = imu_channels_dict["imu"]["tracked_point"].unique()

# Print the unique tracked points (body parts) to get an overview of the monitored locations.
print(tracked_points)
# Out:
# ['head' 'sternum' 'left_upper_arm' 'left_fore_arm' 'right_upper_arm'
#  'right_fore_arm' 'pelvis' 'left_thigh' 'left_shank' 'left_foot'
#  'right_thigh' 'right_shank' 'right_foot' 'left_ankle' 'right_ankle']

# %% [markdown]
# **Step 7**
# - Visualize magnituede of acceleration for some tracked points

# %%
# Define the body segments of interest for plotting
desired_tracked_points = ["head", "sternum", "pelvis", "left_foot"]

# Set up the plot
plt.figure(figsize=(18, 8))

# Loop over each body segment and plot the acceleration magnitude
for tracked_point in desired_tracked_points:
    # Retrieve the acceleration components for x, y, and z axes
    acc_x = imu_data_dict["imu"][f"{tracked_point}_ACCEL_x"]
    acc_y = imu_data_dict["imu"][f"{tracked_point}_ACCEL_y"]
    acc_z = imu_data_dict["imu"][f"{tracked_point}_ACCEL_z"]

    # Calculate the acceleration magnitude using the norm of the x, y, and z components
    acc_mag = np.linalg.norm([acc_x, acc_y, acc_z], axis=0)

    # Plot the data
    plt.plot(np.arange(len(acc_mag)) / sampling_frequency, acc_mag, label=tracked_point)

# Add labels, title, and legend to the plot
plt.xlabel("Time (s)")
plt.ylabel(f"Acceleration ({mapping_type_units['ACCEL']})")
plt.title("Magnitude of Acceleration for Some Tracked Points")
plt.legend()
plt.show()

# %% [markdown]
# #### Kiel Motion Toolbox Analysis (KielMAT)
#
# Now, we learned how to use Python and become familiar with some movement data types, we can go further to analyze our movement data using KielMAT:
#
# KielMAT is an open-source Python-based toolbox for processing human motion data which:
#   - Comprises comprehensive suite of clinically validated algorithms
#   - Can be used for identifying patterns in motion data across various time scales
#   - Can be applied both in clinical and in home assessment environments
#   - Includes examples and documentations demonstrating functionality of algorithms
#
# You can use [KielMAT](https://neurogeriatricskiel.github.io/KielMAT/) and contribute to that.

# %% [markdown]
# Note that we will need to install kielamt before start working with this package:
#   - We will install it by typing `pip install kielmat` in our code cell.

# %%
pip install kielmat
# Out:
# ...
#
# ...
#   Using cached tpcp-0.27.0-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached tpcp-0.27.0-py3-none-any.whl (84 kB)
# ...
#   Attempting uninstall: tpcp
#     Found existing installation: tpcp 2.0.0
#     Uninstalling tpcp-2.0.0:
#       Successfully uninstalled tpcp-2.0.0
# ...
# WARNING: typer 0.12.5 does not provide the extra 'all'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gaitmap 2.5.1 requires tpcp>=0.32.0, but you have tpcp 0.27.0 which is incompatible.

# %% [markdown]
# **Gait Sequence Detection using KielMAT**
#
# - **Algorithm:** We will use [Paraschiv-Ionescu](https://jneuroengrehab.biomedcentral.com/articles/10.1186/s12984-019-0494-z) gait sequence detection algorithm to detect gait sequences from 3D accelerometer data from IMU.
#
# - **Data:** We will use 3D acceleration data from IMU placed on lower back.

# %% [markdown]
# **Step 1**
# - Import Necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from kielmat.modules.gsd import ParaschivIonescuGaitSequenceDetection # Importing Paraschiv-Ionescu gait sequence detection module from the kielmat package

# %% [markdown]
# **Step 2**
# - Load channel and motion data from GAMMA repository for `sub-002` which performs `walkSlow` task.

# %%
# URL of the raw .tsv file on GitHub containing IMU channel and motion information
channel_url = "https://github.com/neurogeriatricskiel/gamma_2024/blob/main/datasets/keepcontrol/sub-pp002/motion/sub-pp002_task-walkSlow_tracksys-imu_channels.tsv?raw=True"
motion_url = "https://github.com/neurogeriatricskiel/gamma_2024/blob/main/datasets/keepcontrol/sub-pp002/motion/sub-pp002_task-walkSlow_tracksys-imu_motion.tsv?raw=True"

# Read the TSV file into a DataFrame using pandas dataframe library
df_channel = pd.read_csv(channel_url, header=0, sep="\t")
df_data = pd.read_csv(motion_url, header=0, sep="\t")

# The 'name' column contains the names of the IMU channels
channel_names = df_channel["name"].values

# The 'type' column contains the types of the IMU channels
channel_type = df_channel["type"].values

# The 'tracked_point' column contains the types of the IMU channels
channel_tracked_points = df_channel["tracked_point"].values

# This ensures that we only keep the relevant IMU data associated with the specified channels
df_data = df_data[channel_names]

# Initialize an empty dictionary to store IMU channels and motion data
imu_channels_dict = {}
imu_data_dict = {}

# Store filtered IMU channel and motion data DataFrame in the dictionary under the key "imu"
imu_data_dict["imu"] = df_data
imu_channels_dict["imu"] = df_channel

# Create a dictionary mapping each channel type to its corresponding units
mapping_type_units = {
    ch_type: imu_channels_dict["imu"][imu_channels_dict["imu"]["type"] == ch_type]["units"].iloc[0]
    for ch_type in imu_channels_dict["imu"]["type"].unique()
}

# %% [markdown]
# **Step 2**
# - Extract pelvis acceleration data and its corresponding unit

# %%
# Step 1: Assign 'pelvis' as the variable for the tracked point
tracked_point = 'pelvis'

# Step 2: Create a list of column names for the pelvis acceleration data
# This constructs names like 'pelvis_ACCEL_x', 'pelvis_ACCEL_y', 'pelvis_ACCEL_z'
accel_column_names = [f"{tracked_point}_ACCEL_{axis}" for axis in "xyz"]
print(f"Acceleration Column Names: {accel_column_names}")

# Step 3: Extract the acceleration data for the pelvis using the constructed column names
pelvis_accel_data = imu_data_dict['imu'][accel_column_names]

# Step 4: Get the acceleration unit from the channels that contain 'ACCEL' in their name
# This selects the first matching unit from the DataFrame
pelvis_accel_unit = imu_channels_dict['imu'][imu_channels_dict['imu']["name"].str.contains("ACCEL")]["units"].iloc[0]

# Step 5: Print the extracted acceleration data along with its unit
print(f"Acceleration Data ({pelvis_accel_unit}):\n{pelvis_accel_data}")
# Out:
# Acceleration Column Names: ['pelvis_ACCEL_x', 'pelvis_ACCEL_y', 'pelvis_ACCEL_z']
# Acceleration Data (g):
#       pelvis_ACCEL_x  pelvis_ACCEL_y  pelvis_ACCEL_z
# 0           0.995614       -0.013190        0.150383
# 1           0.992670       -0.016120        0.153814
# 2           0.990240       -0.015625        0.149906
# 3           0.991688       -0.009284        0.162105
# 4           0.992670       -0.014167        0.158198
# ...              ...             ...             ...
# 2579        1.074216        0.154295        0.236820
# 2580        1.077160        0.131834        0.256833
# 2581        1.082534        0.103514        0.248541
# 2582        1.076179        0.064452        0.245111
# 2583        1.088376        0.032226        0.226565
#
# [2584 rows x 3 columns]

# %% [markdown]
# **Step 3**
# - Extract sampling frequency of acceleration data

# %%
# Step 1: Filter the DataFrame for rows where the tracked point is 'pelvis'
pelvis_data = imu_channels_dict['imu'].loc[imu_channels_dict['imu']['tracked_point'] == 'pelvis']

# Step 2: Extract the 'sampling_frequency' column from the filtered data
sampling_frequency_data = pelvis_data['sampling_frequency']
print(f"Sampling Frequencies for Pelvis Data: {sampling_frequency_data}")

# Step 3: Get the unique sampling frequency values
unique_sampling_frequencies = sampling_frequency_data.unique()
print(f"Unique Sampling Frequencies: {unique_sampling_frequencies}")

# Step 4: Convert the first unique value to float
accel_sampling_frequency = unique_sampling_frequencies[0].astype(float)

# Step 5: Print the final sampling frequency
print(f"Acceleration data was sampled at {accel_sampling_frequency} Hz")
# Out:
# Sampling Frequencies for Pelvis Data: 54    200
# 55    200
# 56    200
# 57    200
# 58    200
# 59    200
# 60    200
# 61    200
# 62    200
# Name: sampling_frequency, dtype: int64
# Unique Sampling Frequencies: [200]
# Acceleration data was sampled at 200.0 Hz

# %% [markdown]
# **Step 4**
# - Visualisation of pelvis acceleration data

# %%
# Represent the raw acceleration data including components of x, y, and z axis
# Calculate time in minutes by converting sample indices to time based on the sampling frequency
time_in_minutes = [sample / (accel_sampling_frequency * 60) for sample in range(len(pelvis_accel_data))]

# Initialize the plot with a specified figure size
plt.figure(figsize=(12, 6))

# Loop through each axis (x, y, z) and plot the corresponding acceleration data
for axis in "xyz":
    # Plot the acceleration data for each axis against time in minutes
    plt.plot(time_in_minutes, pelvis_accel_data[f"{tracked_point}_ACCEL_{axis}"], label=f'ACCEL_{axis.lower()}')

# Add a title to the plot to describe the data being presented
plt.title("Acceleration Data (Pelvis)")

# Label the x-axis to indicate the time in minutes
plt.xlabel("Time (minutes)")

# Label the y-axis to indicate the units of acceleration
plt.ylabel(f"Acceleration ({pelvis_accel_unit})")

# Display a legend to differentiate between the acceleration data for x, y, and z axes
plt.legend()

# Add a grid to the plot for better readability
plt.grid(True)

# Show the plot to visualize the acceleration data
plt.show()

# %% [markdown]
# **Step 5**
# - Apply Paraschiv-Ionescu gait sequence detection module from KielMAT package

# %% [markdown]
# The inputs of the module are as follows:
#
# - **Input Data:** `data` consist of accelerometer data (N, 3) in x, y, and z axes in pandas Dataframe format.
# - **Sampling Frequency:** `sampling_freq_Hz` is the sampling frequency of the data in Hz.
# - **Tracking System:** `tracking_system` is the name of tracking system as a string and is an optioanl input.
# - **Plot Results:** `plot_results`, if set to True, generates a plot showing the detected gait sequences on the data.

# %%
# Create an instance of the ParaschivIonescuGaitSequenceDetection class
gsd = ParaschivIonescuGaitSequenceDetection()

# Call the gait sequence detection using gsd.detect
gsd = gsd.detect(
    data=pelvis_accel_data, 
    sampling_freq_Hz=accel_sampling_frequency, 
    tracking_system='imu', 
    plot_results=True, 
    dt_data=None
)
# Out:
# 1 gait sequence(s) detected.

# %% [markdown]
# **Step 6**
# - Extract gait sequences info

# %%
# Gait sequences are stored in gait_sequences_ attribute of gsd
gait_sequences = gsd.gait_sequences_
print(gait_sequences)
# Out:
#    onset  duration     event_type tracking_system
# 0  3.125     9.775  gait sequence             imu

# %% [markdown]
# #### Gait and Movement Analysis (gaitmap)
#
# In this section, we will explain how to utilize [Gaitmap package](https://gaitmap.readthedocs.io/en/latest/) to analyze your movement data from left and right feet IMUs.

# %% [markdown]
# **Example**
#
# We will show how dynamic time warping (DWT) implemented by the [BarthDtw](https://ieeexplore.ieee.org/document/6611104) can be used to detect strides using IMU data from left and right feet.

# %% [markdown]
# **Step 1**
#
# We need to install `gaitmap` and `gaitmap_mad` packages before start working:

# %%
pip install gaitmap gaitmap_mad --upgrade
# Out:
# ...
#   Using cached tpcp-2.0.0-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached tpcp-2.0.0-py3-none-any.whl (99 kB)
# ...
#   Attempting uninstall: tpcp
#     Found existing installation: tpcp 0.27.0
#     Uninstalling tpcp-0.27.0:
#       Successfully uninstalled tpcp-0.27.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kielmat 0.0.5 requires tpcp<0.28.0,>=0.27.0, but you have tpcp 2.0.0 which is incompatible.

# %% [markdown]
# **Step 2**
#
# - Import necessary libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import vqf # A Versatile Quaternion-based Filter for IMU Orientation Estimation.
from gaitmap.stride_segmentation import BarthDtw # A class for segmenting strides using Dynamic Time Warping (DTW).
from gaitmap.utils.coordinate_conversion import convert_to_fbf # A class to convert dataset to a foot-based frame (FBF) for standardized gait analysis.
from gaitmap.event_detection import RamppEventDetection # A class for detecting important stride events
from gaitmap.parameters import TemporalParameterCalculation # A classs for calculating temporal parameters

# %% [markdown]
# **Step 3**
#
# - Load channel and motion data from GAMMA repository for `sub-002` which performs `walkSlow` task.

# %%
# URL of the raw .tsv file on GitHub containing IMU channel and motion information
channel_url = "https://github.com/neurogeriatricskiel/gamma_2024/blob/main/datasets/keepcontrol/sub-pp002/motion/sub-pp002_task-walkSlow_tracksys-imu_channels.tsv?raw=True"
motion_url = "https://github.com/neurogeriatricskiel/gamma_2024/blob/main/datasets/keepcontrol/sub-pp002/motion/sub-pp002_task-walkSlow_tracksys-imu_motion.tsv?raw=True"

# Read the TSV file into a DataFrame using pandas dataframe library
df_channel = pd.read_csv(channel_url, header=0, sep="\t")
df_data = pd.read_csv(motion_url, header=0, sep="\t")

# The 'name' column contains the names of the IMU channels
channel_names = df_channel["name"].values

# The 'type' column contains the types of the IMU channels
channel_type = df_channel["type"].values

# The 'tracked_point' column contains the types of the IMU channels
channel_tracked_points = df_channel["tracked_point"].values

# This ensures that we only keep the relevant IMU data associated with the specified channels
df_data = df_data[channel_names]

# Initialize an empty dictionary to store IMU channels and motion data
imu_channels_dict = {}
imu_data_dict = {}

# Store filtered IMU channel and motion data DataFrame in the dictionary under the key "imu"
imu_data_dict["imu"] = df_data
imu_channels_dict["imu"] = df_channel

# Create a dictionary mapping each channel type to its corresponding units
mapping_type_units = {
    ch_type: imu_channels_dict["imu"][imu_channels_dict["imu"]["type"] == ch_type]["units"].iloc[0]
    for ch_type in imu_channels_dict["imu"]["type"].unique()
}

# This extracts the unique sampling frequency value for the specified tracked point
fs = imu_channels_dict['imu'].loc[
    imu_channels_dict['imu']['tracked_point'] == 'pelvis', 'sampling_frequency'
].unique()[0].astype(float)

# %% [markdown]
# **Step 5**
#
# - Specify `left_foot` and `right_foot` as desired tracked points.
#
# - Extract 3D acceleration and gyro data for each tracked point and convert them to numpy array.

# %%
# Specify the tracked points that will be used for analysis
left_foot = "left_foot"
right_foot = "right_foot"

# Extract gyroscope and accelerometer data for the left and right foot and convert them to numpy array
gyr_left = imu_data_dict["imu"][[f"{left_foot}_GYRO_{x}" for x in "xyz"]].to_numpy()
acc_left = imu_data_dict["imu"][[f"{left_foot}_ACCEL_{x}" for x in "xyz"]].to_numpy()

gyr_right = imu_data_dict["imu"][[f"{right_foot}_GYRO_{x}" for x in "xyz"]].to_numpy()
acc_right = imu_data_dict["imu"][[f"{right_foot}_ACCEL_{x}" for x in "xyz"]].to_numpy()

# %% [markdown]
# **Step 6**
#
# Before using `gaitmap` package, we need to estimate orientation of the IMUs in a Global Coordinate System

# %% [markdown]
# For orientaton estimation, we will use the [versatile quaternion filter](https://vqf.readthedocs.io/en/latest/getting_started.html) (VQF, Laidig and Seel, 2023).

# %% [markdown]
# **What is VQF?**
#
# - VQF is a tool used to estimate the orientation of an object based on data from sensors, like accelerometers and gyroscopes.
#
# **How does it Work?**
#
# - `Combining Data`: VQF takes the acceleration and gyro data from IMU sensors and combines them to determine the orientation of the tracked point in three-dimensional space.
#
# - `Orientation Representation`: VQF calculates and provides quaternions at each time step, which capture the orientation of the tracked points during the movement.
#
# - `Rotation`: The quaternions is then used to rotate the IMU data.

# %% [markdown]
#   - **Contiguous Memory**:
#
#     In contiguous memory blocks, the array is stored sequentially, without gaps ([numpy.ascontiguousarray](https://numpy.org/doc/stable/reference/generated/numpy.ascontiguousarray.html)).

# %%
# Ensure the data is in contiguous memory
gyr_left = np.ascontiguousarray(gyr_left, dtype=np.float64)
acc_left = np.ascontiguousarray(acc_left, dtype=np.float64)
gyr_right = np.ascontiguousarray(gyr_right, dtype=np.float64)
acc_right = np.ascontiguousarray(acc_right, dtype=np.float64)

# %% [markdown]
#   - **Unit Conversion**:
#
#     Perform necessary conversions to ensure that the data is in the correct units for further processing with VQF.

# %%
# If necessary, convert gyroscope data from deg/s to rad/s
gyr_left = gyr_left * np.pi / 180 if mapping_type_units["GYRO"] == "deg/s" else gyr_left
gyr_right = gyr_right * np.pi / 180 if mapping_type_units["GYRO"] == "deg/s" else gyr_right

# If necessary, convert accelerometer data from 'g' to m/s^2
acc_left = acc_left * 9.81 if mapping_type_units["ACCEL"] == "g" else acc_left
acc_right = acc_right * 9.81 if mapping_type_units["ACCEL"] == "g" else acc_right

# %% [markdown]
# - **Rotate acceleration and gyro of tracked points using estimated quaternion by [VQF](https://vqf.readthedocs.io/en/latest/ref_cython.html#vqf.VQF.updateBatch)**:

# %%
# Define the sample time based on the sampling frequency
Ts = 1 / fs
print(f"Sample time (Ts) is set to: {Ts} seconds")

# Initialize the versatile quaternion filter for left and right foot IMU data
vqf_left = vqf.VQF(Ts)
vqf_right = vqf.VQF(Ts)

# Run the orientation estimation for the left foot
out_left = vqf_left.updateBatch(gyr_left, acc_left)

# Run the orientation estimation for the right foot
out_right = vqf_right.updateBatch(gyr_right, acc_right)

# 'out_left' and 'out_right' will now contain the estimated quaternions for both feet.
# Initialize arrays to hold the rotated acceleration and gyroscope data for left and right foot
acc_rot_left = np.zeros_like(acc_left)  # Array for rotated acceleration data for left foot
gyr_rot_left = np.zeros_like(gyr_left)  # Array for rotated gyroscope data for left foot

acc_rot_right = np.zeros_like(acc_right)  # Array for rotated acceleration data for right foot
gyr_rot_right = np.zeros_like(gyr_right)  # Array for rotated gyroscope data for right foot

# Loop through each time point to perform quaternion rotation for the left foot
for t in range(len(acc_left)):
    # Rotate the acceleration vector using the estimated quaternion at time t for the left foot
    acc_rot_left[t] = vqf_left.quatRotate(out_left["quat6D"][t], acc_left[t])

    # Rotate the gyroscope vector using the estimated quaternion at time t for the left foot
    gyr_rot_left[t] = vqf_left.quatRotate(out_left["quat6D"][t], gyr_left[t])

print("Quaternion rotation for the left foot completed.")

# Loop through each time point to perform quaternion rotation for the right foot
for t in range(len(acc_right)):
    # Rotate the acceleration vector using the estimated quaternion at time t for the right foot
    acc_rot_right[t] = vqf_right.quatRotate(out_right["quat6D"][t], acc_right[t])

    # Rotate the gyroscope vector using the estimated quaternion at time t for the right foot
    gyr_rot_right[t] = vqf_right.quatRotate(out_right["quat6D"][t], gyr_right[t])

print("Quaternion rotation for the right foot completed.")

# Print the final results of the rotated data
print(f"Rotated acceleration of left foot: {acc_rot_left}")
print(f"Rotated gyroscope of left foot: {gyr_rot_left}")
print(f"Rotated acceleration of right foot: {acc_rot_right}")
print(f"Rotated gyroscope of right foot: {gyr_rot_right}")
# Out:
# Sample time (Ts) is set to: 0.005 seconds
# Quaternion rotation for the left foot completed.
# Quaternion rotation for the right foot completed.
# Rotated acceleration of left foot: [[-2.66453526e-15 -2.22044605e-16  9.83638000e+00]
#  [-1.69017192e-02  2.61077742e-02  9.83124202e+00]
#  [-1.86748608e-02 -1.12889126e-03  9.77453834e+00]
#  ...
#  [-1.02784295e+00 -3.89673615e-01  1.15691783e+01]
#  [-1.97906800e+00  1.68932741e+00  1.11982287e+01]
#  [-1.89242726e+00  3.37724502e+00  1.04031059e+01]]
# Rotated gyroscope of left foot: [[ 0.00086704  0.00211585  0.0044462 ]
#  [-0.00995847  0.00369677  0.0070097 ]
#  [-0.00376753  0.0020597   0.00541902]
#  ...
#  [ 0.61915577 -0.30753977  0.80829939]
#  [ 0.40441503 -0.31520891  0.62782389]
#  [ 0.30013038 -0.3087831   0.5887019 ]]
# Rotated acceleration of right foot: [[ 8.88178420e-16 -2.77555756e-17  9.81855949e+00]
#  [-2.04442396e-02 -2.37530085e-02  9.82525799e+00]
#  [-1.27073120e-02 -1.93267461e-02  9.84683643e+00]
#  ...
# ...

# %% [markdown]
# - **Unit Conversion**:
#
#     Convert units of the rotated acceleration and gyroscope data to be compatibale with `gaitmap` package requirements.

# %%
# Convert the rotated gyroscope data to deg/s if needed
gyr_rot_left = gyr_rot_left * 180 / np.pi if mapping_type_units["GYRO"] == "deg/s" else gyr_rot_left
gyr_rot_right = gyr_rot_right * 180 / np.pi if mapping_type_units["GYRO"] == "deg/s" else gyr_rot_right

# Convert the rotated accelerometer data to 'g' if needed
acc_rot_left = acc_rot_left / 9.81 if mapping_type_units["ACCEL"] == "g" else acc_rot_left
acc_rot_right = acc_rot_right / 9.81 if mapping_type_units["ACCEL"] == "g" else acc_rot_right

# %% [markdown]
# - **Combine Rotated Acceleration and Gyro Data**:

# %%
# Define the foot sensor names
left_foot = "left_foot"
right_foot = "right_foot"

# Create a dictionary for the rotated data for both left and right foot
rotated_data_dict = {
    "sensor": ["left_sensor"] * 6 + ["right_sensor"] * 6,
    "axis": [
        "acc_x", "acc_y", "acc_z", "gyr_x", "gyr_y", "gyr_z",  # Left foot axes
        "acc_x", "acc_y", "acc_z", "gyr_x", "gyr_y", "gyr_z"   # Right foot axes
    ]
}

# Create a pandas MultiIndex from the 'sensor' and 'axis'
multiindex_columns = pd.MultiIndex.from_arrays(
    [rotated_data_dict["sensor"], rotated_data_dict["axis"]],
    names=["sensor", "axis"]
)

# Combine the rotated IMU data into one array (left and right foot, side by side)
combined_data = np.hstack([acc_rot_left, gyr_rot_left, acc_rot_right, gyr_rot_right])

# Create the DataFrame using the MultiIndex for columns and the combined data for values
imu_data_rotated = pd.DataFrame(combined_data, columns=multiindex_columns)

# Display the first few rows of the rotated IMU data
print(imu_data_rotated.head())
# Out:
# sensor   left_sensor                                                        \
# axis           acc_x         acc_y     acc_z     gyr_x     gyr_y     gyr_z
# 0      -2.716142e-16 -2.263452e-17  1.002689  0.049678  0.121229  0.254748
# 1      -1.722907e-03  2.661343e-03  1.002165 -0.570578  0.211809  0.401626
# 2      -1.903656e-03 -1.150756e-04  0.996385 -0.215864  0.118012  0.310487
# 3      -1.055527e-03 -1.252985e-03  1.006123 -0.294224  0.519736 -0.013210
# 4       5.209902e-03  2.595212e-03  0.997541  0.110340 -0.301048 -0.319783
#
# sensor  right_sensor
# axis           acc_x         acc_y     acc_z     gyr_x     gyr_y     gyr_z
# 0       9.053807e-17 -2.829315e-18  1.000873 -0.509066  0.001361 -0.009482
# 1      -2.084020e-03 -2.421306e-03  1.001555  0.014844 -0.344094 -0.315307
# 2      -1.295343e-03 -1.970107e-03  1.003755  0.183596  0.000780 -0.212394
# 3      -3.238975e-03 -2.210986e-03  1.003256 -0.228038  0.519208  0.136287
# ...

# %% [markdown]
# **Step 7**
#
# - Convert the rotated data to a foot-based frame (FBF) for standardized gait analysis using [conevrt_to_fbf](https://gaitmap.readthedocs.io/en/stable/modules/generated/utils/coordinate_conversion/gaitmap.utils.coordinate_conversion.convert_to_fbf.html#gaitmap.utils.coordinate_conversion.convert_to_fbf).

# %%
# Convert the rotated data to the foot-frame of reference
data_rotated = convert_to_fbf(imu_data_rotated, left_like="left_", right_like="right_")

# Displays the processed IMU data for both the left and right foot sensors
print(data_rotated)
# Out:
#        left_sensor                                                            \
#             acc_pa        acc_ml    acc_si     gyr_pa     gyr_ml      gyr_si
# 0    -2.716142e-16 -2.263452e-17 -1.002689  -0.049678  -0.121229   -0.254748
# 1    -1.722907e-03  2.661343e-03 -1.002165   0.570578  -0.211809   -0.401626
# 2    -1.903656e-03 -1.150756e-04 -0.996385   0.215864  -0.118012   -0.310487
# 3    -1.055527e-03 -1.252985e-03 -1.006123   0.294224  -0.519736    0.013210
# 4     5.209902e-03  2.595212e-03 -0.997541  -0.110340   0.301048    0.319783
# ...            ...           ...       ...        ...        ...         ...
# 2579  5.754132e-03 -7.250688e-01 -1.093171 -32.642998  19.235909 -110.881736
# 2580 -6.946237e-02 -3.974975e-01 -1.164410 -38.985242  17.308554  -71.887327
# 2581 -1.047750e-01 -3.972208e-02 -1.179325 -35.475012  17.620731  -46.312143
# 2582 -2.017399e-01  1.722046e-01 -1.141512 -23.171274  18.060140  -35.971659
# ...

# %% [markdown]
# Summary of output:
#
# - **Acceleration Data**:
#   - `acc_pa`: Acceleration in the anterior-posterior direction.
#   - `acc_ml`: Acceleration in the medio-lateral direction.
#   - `acc_si`: Acceleration in the superior-inferior direction.
#
# - **Gyroscope Data**:
#   - `gyr_pa`: Angular velocity in the anterior-posterior direction.
#   - `gyr_ml`: Angular velocity in the medio-lateral direction.
#   - `gyr_si`: Angular velocity in the superior-inferior direction.

# %% [markdown]
# **Step 8**
#
# - Apply Dynamic Time Warping (DTW) to analyze IMU data and identify similarities between time-series sequences uisng [BarthDtw](https://gaitmap.readthedocs.io/en/v2.4.0/modules/generated/stride_segmentation/gaitmap.stride_segmentation.BarthDtw.html#gaitmap.stride_segmentation.BarthDtw).
#
# - This process involves aligning the sequences and identifying strides in the data.

# %%
# Initialize the Barth Dynamic Time Warping (DTW) algorithm
dtw = BarthDtw()

# Apply DTW for segmenting the data using the IMU sampling rate
dtw = dtw.segment(data=data_rotated, sampling_rate_hz=fs)

# %% [markdown]
# **Step 9**

# %% [markdown]
# - Print start and end times of all identified strides.

# %%
# Extract the stride list for the left foot sensor
stride_list_left = dtw.stride_list_["left_sensor"]

# Print the number of detected strides
print(f"{len(stride_list_left)} strides were detected.")

# Display the first few rows of the detected stride list
stride_list_left.head()
# Out:
# 5 strides were detected.
#       start   end
# s_id
# 0       806  1081
# 1      1081  1384
# 2      1384  1658
# 3      1658  1958
# 4      1958  2250

# %% [markdown]
# - Plot the identified strides for left foot.

# %%
# Define the sensor to be used for plotting (left foot sensor)
sensor = "left_sensor"

# Create a plot for gyroscope data on the medio-lateral axis
plt.figure(figsize=(12, 4))

# Plot the gyroscope data for the medio-lateral axis
plt.plot(dtw.data[sensor]["gyr_ml"], color="blue", label="Gyro Medio-Lateral")
plt.ylabel("Gyro medio-lateral [deg/s]")

# Add stride annotations (gray shaded areas) to the gyroscope plot
for start, end in dtw.stride_list_[sensor][["start", "end"]].values:
    plt.axvspan(start, end, alpha=0.5, color="gray")

# Add title and legend
plt.title("Gyroscope Data for Left Foot Sensor")
plt.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# - Event Detection using [RamppEventDetection](https://gaitmap.readthedocs.io/en/v2.4.0/modules/generated/event_detection/gaitmap.event_detection.RamppEventDetection.html#gaitmap.event_detection.RamppEventDetection)

# %%
# Initialize the RamppEventDetection object for detecting events
ed = RamppEventDetection()

# Perform event detection for each stride in the identified stride list
ed = ed.detect(data=data_rotated, stride_list=dtw.stride_list_, sampling_rate_hz=fs)

# After detection, 'ed' will contain the important stride events such as initial contact (IC) and final contact (FC) for each stride.
segmented_events_left = ed.segmented_event_list_["left_sensor"]

# Display the first few rows of the detected gait events for the left foot
segmented_events_left.head()
# Out:
#       start   end      ic      tc  min_vel
# s_id
# 0       806  1081   916.0   823.0    995.0
# 1      1081  1384  1196.0  1102.0   1269.0
# 2      1384  1658  1489.0  1401.0   1535.0
# 3      1658  1958  1773.0  1680.0   1893.0
# 4      1958  2250  2068.0  1979.0   2112.0

# %% [markdown]
# - Temporal Parameter Calculation using [TemporalParameterCalculation](https://gaitmap.readthedocs.io/en/v2.4.0/modules/generated/parameters/gaitmap.parameters.TemporalParameterCalculation.html)

# %%
# Initialize the TemporalParameterCalculation object to handle temporal parameter calculations
temporal_paras = TemporalParameterCalculation()

# Calculate the temporal parameters using the identified stride events
temporal_paras = temporal_paras.calculate(
    stride_event_list=ed.min_vel_event_list_,  # List of stride events containing minimal velocity information
    sampling_rate_hz=fs                        # Sampling frequency of the data
)

# Access and print the pretty-printed temporal parameters for the left foot sensor
# This will provide a user-friendly display of the calculated parameters such as stride time, swing time, and stance time
temporal_paras.parameters_pretty_["left_sensor"]
# Out:
#            stride time [s]  swing time [s]  stance time [s]
# stride id
# 0                    1.400           0.470            0.930
# 1                    1.465           0.440            1.025
# 2                    1.420           0.465            0.955
# 3                    1.475           0.445            1.030
